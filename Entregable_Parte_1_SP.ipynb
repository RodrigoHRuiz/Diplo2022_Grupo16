# %% [markdown]
# <a href="https://colab.research.google.com/github/RodrigoHRuiz/Diplo2022_Grupo16/blob/main/Entregable_Parte_1_SP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import io
import matplotlib
import matplotlib.pyplot as plt
import numpy
import pandas as pd
import seaborn

seaborn.set_context('talk')

# %%
url = 'https://cs.famaf.unc.edu.ar/~mteruel/datasets/diplodatos/sysarmy_survey_2020_processed.csv'
df = pd.read_csv(url)
df
# Out:
#      profile_gender  profile_age work_country  \
# 0             Mujer           26    Argentina
# 1            Hombre           29    Argentina
# 2             Mujer           22    Argentina
# 3            Hombre           39    Argentina
# 4            Hombre           32    Argentina
# ...             ...          ...          ...
# 6090         Hombre           37    Argentina
# 6091         Hombre           38    Argentina
# 6092         Hombre           24    Argentina
# 6093         Hombre           28    Argentina
# 6094         Hombre           33    Argentina
#
#                         work_province  profile_years_experience  \
# 0     Ciudad Autónoma de Buenos Aires                       3.0
# 1                          Corrientes                       5.0
# 2     Ciudad Autónoma de Buenos Aires                       2.0
# 3                          Corrientes                      15.0
# 4     Ciudad Autónoma de Buenos Aires                       9.0
# ...                               ...                       ...
# 6090  Ciudad Autónoma de Buenos Aires                      13.0
# 6091  Ciudad Autónoma de Buenos Aires                      12.0
# 6092  Ciudad Autónoma de Buenos Aires                       2.0
# 6093                         La Pampa                       5.0
# 6094                              GBA                       5.0
#
#       work_years_in_company  work_years_in_current_position  \
# 0                       3.0                             3.0
# 1                       2.0                             2.0
# 2                       0.0                             0.0
# 3                      15.0                            13.0
# 4                       6.0                             6.0
# ...                     ...                             ...
# 6090                    6.0                             6.0
# 6091                    5.0                             5.0
# 6092                    2.0                             2.0
# 6093                    3.0                             2.0
# 6094                    5.0                             3.0
#
#       work_people_in_charge_of profile_studies_level  \
# 0                            0         Universitario
# 1                            4         Universitario
# 2                            0            Secundario
# 3                            5              Posgrado
# 4                            0         Universitario
# ...                        ...                   ...
# 6090                         0             Terciario
# 6091                         0         Universitario
# 6092                         0             Terciario
# 6093                         0             Terciario
# 6094                         0             Terciario
#
#      profile_studies_level_state  ... work_has_violence_situations  \
# 0                       En curso  ...         En mi trabajo actual
# 1                       En curso  ...                        Jamás
# 2                     Completado  ...       En un trabajo anterior
# 3                     Incompleto  ...         En mi trabajo actual
# 4                       En curso  ...                        Jamás
# ...                          ...  ...                          ...
# 6090                  Completado  ...         En mi trabajo actual
# 6091                    En curso  ...                        Jamás
# 6092                    En curso  ...                        Jamás
# 6093                    En curso  ...                        Jamás
# 6094                  Incompleto  ...                        Jamás
#
#      profile_sexual_orientation profile_has_disabilities  \
# 0                    Homosexual                      NaN
# 1                  Heterosexual                   Visual
# 2              Bisexual o queer                      NaN
# 3                  Heterosexual                      NaN
# 4                  Heterosexual                      NaN
# ...                         ...                      ...
# 6090               Heterosexual                      NaN
# 6091               Heterosexual                      NaN
# 6092               Heterosexual                      NaN
# 6093               Heterosexual                      NaN
# 6094               Heterosexual                       no
#
#      profile_has_disabilities_hiring_difficulties company_employee_number  \
# 0                                             NaN                501-1000
# 1                                              No                 201-500
# 2                                              No               2001-5000
# 3                                             NaN                501-1000
# 4                                             NaN                   11-50
# ...                                           ...                     ...
# 6090                                           No                501-1000
# 6091                                          NaN               2001-5000
# 6092                                          NaN                 201-500
# 6093                                           No                  51-100
# 6094                                           No                501-1000
#
#                               company_main_activity company_recommended  \
# 0     Servicios / Consultoría de Software / Digital                   7
# 1                                  Otras industrias                   8
# 2                                  Otras industrias                   6
# 3                                  Otras industrias                   7
# 4     Servicios / Consultoría de Software / Digital                   6
# ...                                             ...                 ...
# 6090                               Otras industrias                   7
# 6091                               Otras industrias                   8
# 6092                    Producto basado en Software                   7
# 6093  Servicios / Consultoría de Software / Digital                   5
# 6094                               Otras industrias                   9
#
#      company_diversity_policies  \
# 0                             2
# 1                             9
# 2                             9
# 3                             6
# 4                             6
# ...                         ...
# 6090                          8
# 6091                         10
# 6092                          9
# 6093                          7
# 6094                          7
#
#                                  company_extra_benefits  \
# 0     Capacitaciones y/o cursos, Comidas pagas / sub...
# 1     Horarios flexibles, Stock options / RSUs, Viát...
# 2     Clases de gimnasia online, Comidas pagas / sub...
# 3     Abono de celular, Capacitaciones y/o cursos, C...
# 4     Clases de idiomas, Horarios flexibles, Vacacio...
# ...                                                 ...
# 6090                                           Viáticos
# 6091  Abono de celular, Capacitaciones y/o cursos, D...
# 6092  Capacitaciones y/o cursos, Clases de idiomas, ...
# 6093                          Capacitaciones y/o cursos
# 6094   Abono de celular, Comidas pagas / subvencionadas
#
#      company_best_companies_city
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 6090                         NaN
# 6091                         NaN
# 6092               Mercado Libre
# 6093                 Solo Nubity
# 6094                         NaN
#
# [6095 rows x 48 columns]

# %%
# complete here if you want to include more columns
relevant_columns = ['tools_programming_languages', 'salary_monthly_NETO']
relevant_columns
# Out:
# ['tools_programming_languages', 'salary_monthly_NETO']

# %%
df.tools_programming_languages[:10]
# Out:
# 0                                              Ninguno
# 1                             HTML, Javascript, Python
# 2                                              Ninguno
# 3    Bash/Shell, C, CSS, HTML, Java, Javascript, PH...
# 4               CSS, HTML, Javascript, SQL, TypeScript
# 5                                     Java, Javascript
# 6                                           Javascript
# 7                                     Java, Javascript
# 8                          Javascript, PHP, TypeScript
# 9              Assembler, Bash/Shell, C, C#, Python, R
# Name: tools_programming_languages, dtype: object

# %%
# Convert the comma-separated string of languages to a list of string.
# Remove 'ninguno de los anteriores' option, spaces and training commas.
def split_languages(languages_str):
  if not isinstance(languages_str, str):
    return []
  # Remove 'other' option
  languages_str = languages_str.lower()\
    .replace('ninguno de los anteriores', '')
  # Split string into list of items
  # Remove spaces and commas for each item
  return [lang.strip().replace(',', '')
          for lang in languages_str.split()]

# Create a new column with the list of languages
df.loc[:, 'cured_programming_languages'] = df.tools_programming_languages\
    .apply(split_languages)
if 'cured_programming_languages' not in relevant_columns:
    relevant_columns.append('cured_programming_languages') 

# Duplicate each row of df for each programming language
# mentioned in the response.
# We only include in df_lang the columns we are going to analyze later, so we
# don't duplicate innecesary information.
df_lang = df.cured_programming_languages\
    .apply(pd.Series).stack()\
    .reset_index(level=-1, drop=True).to_frame()\
    .join(df[relevant_columns])\
    .rename(columns={0: 'programming_language'})
# Horrible programming style! But a lot of data science code can be written with
# as concatenations of functions (pipelines), and there's no elegant way of
# doing that on Python.
df_lang[:10]
# Out:
#   programming_language                        tools_programming_languages  \
# 0              ninguno                                            Ninguno
# 1                 html                           HTML, Javascript, Python
# 1           javascript                           HTML, Javascript, Python
# 1               python                           HTML, Javascript, Python
# 2              ninguno                                            Ninguno
# 3           bash/shell  Bash/Shell, C, CSS, HTML, Java, Javascript, PH...
# 3                    c  Bash/Shell, C, CSS, HTML, Java, Javascript, PH...
# 3                  css  Bash/Shell, C, CSS, HTML, Java, Javascript, PH...
# 3                 html  Bash/Shell, C, CSS, HTML, Java, Javascript, PH...
# 3                 java  Bash/Shell, C, CSS, HTML, Java, Javascript, PH...
#
#    salary_monthly_NETO                        cured_programming_languages
# 0              43000.0                                          [ninguno]
# 1              63000.0                         [html, javascript, python]
# 1              63000.0                         [html, javascript, python]
# 1              63000.0                         [html, javascript, python]
# 2             127000.0                                          [ninguno]
# 3             102000.0  [bash/shell, c, css, html, java, javascript, p...
# 3             102000.0  [bash/shell, c, css, html, java, javascript, p...
# 3             102000.0  [bash/shell, c, css, html, java, javascript, p...
# 3             102000.0  [bash/shell, c, css, html, java, javascript, p...
# 3             102000.0  [bash/shell, c, css, html, java, javascript, p...

# %%
from pandas._libs import index
cant2 = df_lang[['salary_monthly_NETO']]
cant2[1]= cant2.index
cant2 = cant2.rename(columns={1: 'indice'})
cant3 = cant2.index.value_counts().reset_index().rename(columns={'index': 'indice'})
#cant4 = pd.merge(cant2,cant3,how='inner')
print(cant2.head(12))
print(cant3.head(2))
cant = pd.merge(cant2,cant3,on='indice',how='inner')
cant
# Out:
#    salary_monthly_NETO  indice
# 0              43000.0       0
# 1              63000.0       1
# 1              63000.0       1
# 1              63000.0       1
# 2             127000.0       2
# 3             102000.0       3
# 3             102000.0       3
# 3             102000.0       3
# 3             102000.0       3
# 3             102000.0       3
# 3             102000.0       3
# 3             102000.0       3
#    indice   0
# 0    2866  18
# 1     163  18
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        salary_monthly_NETO  indice  0
# 0                  43000.0       0  1
# 1                  63000.0       1  3
# 2                  63000.0       1  3
# 3                  63000.0       1  3
# 4                 127000.0       2  1
# ...                    ...     ... ..
# 17995                 72.0    6093  8
# 17996                 72.0    6093  8
# 17997                 72.0    6093  8
# 17998                 72.0    6093  8
# 17999                 72.0    6093  8
#
# [18000 rows x 3 columns]

# %%
language_count = df_lang.programming_language.value_counts()\
    .reset_index()\
    .rename(columns={'index': 'language', 'programming_language': 'frequency'})

language_count
# Out:
#        language  frequency
# 0    javascript       2513
# 1           sql       2154
# 2          html       1861
# 3        python       1475
# 4          java       1453
# ..          ...        ...
# 200         xsl          1
# 201    velocity          1
# 202      apache          1
# 203         lex          1
# 204   infobasic          1
#
# [205 rows x 2 columns]

# %%
language_count_new = language_count.loc[language_count['frequency']>5]
#df.loc[df['shield'] > 6]
language_count_new
# Out:
#         language  frequency
# 0     javascript       2513
# 1            sql       2154
# 2           html       1861
# 3         python       1475
# 4           java       1453
# 5            css       1247
# 6     bash/shell        993
# 7            php        891
# 8           .net        823
# 9     typescript        779
# 10            c#        734
# 11       ninguno        331
# 12            go        306
# 13           c++        271
# 14             c        242
# 15           vba        222
# 16        kotlin        191
# 17        groovy        169
# 18          ruby        157
# 19         scala        115
# 20         swift        103
# 21             r         86
# 22         cobol         81
# 23          abap         73
# 24          perl         65
# 25   objective-c         51
# 26        delphi         44
# 27    powershell         41
# 28          dart         38
# 29     assembler         36
# 30  actionscript         35
# 31        matlab         29
# 32          apex         21
# 33     smalltalk         18
# 34          rust         18
# 35        pl/sql         15
# 36        elixir         12
# 37            no         11
# 38       genexus         11
# 39        visual         10
# 40           vb6          8
# 41  powerbuilder          6
# 42        erlang          6

# %%
language_count_new = language_count_new.loc[language_count['language'] != "ninguno"]
language_count_new
# Out:
#         language  frequency
# 0     javascript       2513
# 1            sql       2154
# 2           html       1861
# 3         python       1475
# 4           java       1453
# 5            css       1247
# 6     bash/shell        993
# 7            php        891
# 8           .net        823
# 9     typescript        779
# 10            c#        734
# 12            go        306
# 13           c++        271
# 14             c        242
# 15           vba        222
# 16        kotlin        191
# 17        groovy        169
# 18          ruby        157
# 19         scala        115
# 20         swift        103
# 21             r         86
# 22         cobol         81
# 23          abap         73
# 24          perl         65
# 25   objective-c         51
# 26        delphi         44
# 27    powershell         41
# 28          dart         38
# 29     assembler         36
# 30  actionscript         35
# 31        matlab         29
# 32          apex         21
# 33     smalltalk         18
# 34          rust         18
# 35        pl/sql         15
# 36        elixir         12
# 37            no         11
# 38       genexus         11
# 39        visual         10
# 40           vb6          8
# 41  powerbuilder          6
# 42        erlang          6

# %%
df_cured = df_lang[df_lang.programming_language.isin(language_count_new['language'])]
#df_lang[df_lang.programming_language.isin(interesting_languages)]
df_cured
# Out:
#      programming_language                        tools_programming_languages  \
# 1                    html                           HTML, Javascript, Python
# 1              javascript                           HTML, Javascript, Python
# 1                  python                           HTML, Javascript, Python
# 3              bash/shell  Bash/Shell, C, CSS, HTML, Java, Javascript, PH...
# 3                       c  Bash/Shell, C, CSS, HTML, Java, Javascript, PH...
# ...                   ...                                                ...
# 6093                 java   C, C++, HTML, Java, Javascript, PHP, Python, SQL
# 6093           javascript   C, C++, HTML, Java, Javascript, PHP, Python, SQL
# 6093                  php   C, C++, HTML, Java, Javascript, PHP, Python, SQL
# 6093               python   C, C++, HTML, Java, Javascript, PHP, Python, SQL
# 6093                  sql   C, C++, HTML, Java, Javascript, PHP, Python, SQL
#
#       salary_monthly_NETO                        cured_programming_languages
# 1                 63000.0                         [html, javascript, python]
# 1                 63000.0                         [html, javascript, python]
# 1                 63000.0                         [html, javascript, python]
# 3                102000.0  [bash/shell, c, css, html, java, javascript, p...
# 3                102000.0  [bash/shell, c, css, html, java, javascript, p...
# ...                   ...                                                ...
# 6093                 72.0  [c, c++, html, java, javascript, php, python, ...
# 6093                 72.0  [c, c++, html, java, javascript, php, python, ...
# 6093                 72.0  [c, c++, html, java, javascript, php, python, ...
# 6093                 72.0  [c, c++, html, java, javascript, php, python, ...
# 6093                 72.0  [c, c++, html, java, javascript, php, python, ...
#
# [17414 rows x 4 columns]

# %%
df_lang.shape
# Out:
# (18000, 4)

# %%
df_cured.shape
# Out:
# (17414, 4)

# %%
#Conteos de Datos que no son numéricos, datos categóricos. Pueden ser ordinales o no ordinales.
fig = plt.figure(figsize=(50, 50))
seaborn.countplot(y=df_lang.programming_language, color='steelblue')

# %%
#Conteos de Datos que no son numéricos, datos categóricos. Pueden ser ordinales o no ordinales.
fig = plt.figure(figsize=(50, 50))
seaborn.countplot(y=df_cured.programming_language, color='steelblue')

# %%
plt.figure(figsize=(12, 4))
seaborn.boxplot(x=df_cured.salary_monthly_NETO)
seaborn.despine()

# %%
#Quitar los outliers que están fuera del rango de 2.5 veces Q1 y Q3
Q1 = df_cured["salary_monthly_NETO"].quantile(.25)
Q3 = df_cured["salary_monthly_NETO"].quantile(.75)
IQR = Q3 - Q1
df3 = df_cured[~((df_cured['salary_monthly_NETO']<(Q1 -2.5 * IQR))|(df_cured['salary_monthly_NETO']>(Q3 + 2.5 * IQR)))]
print('Q1: {} ::: Q2: {}'.format(int(Q1),int(Q3)))
print('Q1-2.5*IQR: {}\nQ3+2.5*IQR: {}'.format(int(Q1-2.5*IQR),int(Q3+2.5*IQR)))
plt.figure(figsize=(12, 4))
seaborn.boxplot(x=df3.salary_monthly_NETO)
seaborn.despine()
# Out:
# Q1: 54000 ::: Q2: 110000
# Q1-2.5*IQR: -86000
# Q3+2.5*IQR: 250000

# %%
language_count_new
# Out:
#         language  frequency
# 0     javascript       2513
# 1            sql       2154
# 2           html       1861
# 3         python       1475
# 4           java       1453
# 5            css       1247
# 6     bash/shell        993
# 7            php        891
# 8           .net        823
# 9     typescript        779
# 10            c#        734
# 12            go        306
# 13           c++        271
# 14             c        242
# 15           vba        222
# 16        kotlin        191
# 17        groovy        169
# 18          ruby        157
# 19         scala        115
# 20         swift        103
# 21             r         86
# 22         cobol         81
# 23          abap         73
# 24          perl         65
# 25   objective-c         51
# 26        delphi         44
# 27    powershell         41
# 28          dart         38
# 29     assembler         36
# 30  actionscript         35
# 31        matlab         29
# 32          apex         21
# 33     smalltalk         18
# 34          rust         18
# 35        pl/sql         15
# 36        elixir         12
# 37            no         11
# 38       genexus         11
# 39        visual         10
# 40           vb6          8
# 41  powerbuilder          6
# 42        erlang          6

# %%
df_fer = df_cured[['salary_monthly_NETO','programming_language']]
#df_fer
prom = df_fer.groupby(['programming_language']).mean().reset_index().rename(columns={'programming_language': 'language', 'salary_monthly_NETO': 'Promedio'})
prom
# Out:
#         language       Promedio
# 0           .net   89489.067340
# 1           abap   85617.937606
# 2   actionscript   94278.092514
# 3           apex   72307.416667
# 4      assembler  124223.865429
# 5     bash/shell  110882.139431
# 6              c  121209.941082
# 7             c#   92195.413123
# 8            c++  101538.733132
# 9          cobol  102101.445190
# 10           css   92221.523950
# 11          dart   84366.421053
# 12        delphi  113779.570636
# 13        elixir  193226.875000
# 14        erlang   55971.250000
# 15       genexus   58167.636364
# 16            go  140309.642509
# 17        groovy  109747.354623
# 18          html   91807.318308
# 19          java   99769.704651
# 20    javascript  100349.853843
# 21        kotlin  114617.860456
# 22        matlab   65670.166667
# 23            no   65750.454545
# 24   objective-c  138762.775510
# 25          perl  118390.994531
# 26           php   94281.415584
# 27        pl/sql   73395.800000
# 28  powerbuilder   71512.500000
# 29    powershell   86585.681750
# 30        python  110805.045791
# 31             r  117366.816667
# 32          ruby  162600.003444
# 33          rust  149211.845750
# 34         scala  165968.641027
# 35     smalltalk  155238.611111
# 36           sql   92165.221091
# 37         swift  129177.886598
# 38    typescript  111012.616366
# 39           vb6   59244.625000
# 40           vba   77274.997149
# 41        visual   59789.900000

# %%
final = pd.merge(language_count_new,prom, on='language', how='inner').round(2)
final
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-43fbefc39d00> in <module>()
# ----> 1 final = pd.merge(language_count_new,prom, on='language', how='inner').round(2)
#       2 final
#
# NameError: name 'pd' is not defined
